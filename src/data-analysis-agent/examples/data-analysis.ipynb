# %% [markdown]
# # Data Analysis Agent
#  - we are going to build a data analysis agent
#  - agent that ananlyse files, genrate visualization and share results
#  - Tutorial reference : [Langchain Deep Agent](https://docs.langchain.com/oss/python/deepagents/data-analysis)

# %% [markdown]
# ### The agent we build will :
#  - Accept CSV file for analysis
#  - Perform expoloratory data analysis and creat visuslaization
#  - Share details in the slack channel
